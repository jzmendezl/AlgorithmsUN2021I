# %% [markdown]
# #Certificate Algorithmic Toolbox

# %% [markdown]
# ![certificate.PNG](data:image/png;base64,...)

# %% [markdown]
# https://www.linkedin.com/posts/joe-zafir-m%C3%A9ndez-le%C3%B3n-52989120a_completion-certificate-for-algorithmic-toolbox-activity-6827968342062600192-pSLN
